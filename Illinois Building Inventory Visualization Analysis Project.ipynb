# %% [markdown]
# I will begin by importing some packages.

# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import ipywidgets

# %% [markdown]
# I will be importing the UFO dataset using Professor Naiman's code from the Week 5 In-Class Notebook that can be accessed here: https://uiuc-ischool-dataviz.github.io/is445_spring2022/nbv.html?notebook_name=%2Fis445_spring2022%2Fweek05%2FinClass_week05.ipynb

# %%
ufos = pd.read_csv('https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_AOUAOG_fall2021/master/week05/data/ufo-scrubbed-geocoded-time-standardized-00.csv', 
                  names=["date", "city", "state", "country", 
                        "shape", "duration_seconds", "duration", 
                        "comment", "report_date", "latitude", "longitude"], 
                  parse_dates = ["date", "report_date"])
ufos
# Out:
#                      date                  city state country     shape  \
# 0     1949-10-10 20:30:00            san marcos    tx      us  cylinder
# 1     1949-10-10 21:00:00          lackland afb    tx     NaN     light
# 2     1955-10-10 17:00:00  chester (uk/england)   NaN      gb    circle
# 3     1956-10-10 21:00:00                  edna    tx      us    circle
# 4     1960-10-10 20:00:00               kaneohe    hi      us     light
# ...                   ...                   ...   ...     ...       ...
# 80327 2013-09-09 21:15:00             nashville    tn      us     light
# 80328 2013-09-09 22:00:00                 boise    id      us    circle
# 80329 2013-09-09 22:00:00                  napa    ca      us     other
# 80330 2013-09-09 22:20:00                vienna    va      us    circle
# 80331 2013-09-09 23:00:00                edmond    ok      us     cigar
#
#        duration_seconds    duration  \
# 0                2700.0  45 minutes
# ...

# %%
ufos = ufos.fillna({'country':'unknown', 
                   'state':'unknown', 
                   'shape':'unknown'})
ufos
# Out:
#                      date                  city    state  country     shape  \
# 0     1949-10-10 20:30:00            san marcos       tx       us  cylinder
# 1     1949-10-10 21:00:00          lackland afb       tx  unknown     light
# 2     1955-10-10 17:00:00  chester (uk/england)  unknown       gb    circle
# 3     1956-10-10 21:00:00                  edna       tx       us    circle
# 4     1960-10-10 20:00:00               kaneohe       hi       us     light
# ...                   ...                   ...      ...      ...       ...
# 80327 2013-09-09 21:15:00             nashville       tn       us     light
# 80328 2013-09-09 22:00:00                 boise       id       us    circle
# 80329 2013-09-09 22:00:00                  napa       ca       us     other
# 80330 2013-09-09 22:20:00                vienna       va       us    circle
# 80331 2013-09-09 23:00:00                edmond       ok       us     cigar
#
#        duration_seconds    duration  \
# ...

# %%
nsamples = 1000
downSampleMask = np.random.choice(range(len(ufos)-1),nsamples,replace=False)
downSampleMask
# Out:
# array([17264, 53557, 73088, 68313, 72675, 11970, 62934,   340, 50021,
#        76665, 65612, 48316, 44040, 28122, 65782, 30436, 59226, 70080,
#        35034, 16133, 15427, 58657, 24927, 59533, 46234, 11582, 50129,
#        13604, 26086, 21968, 48608, 66006, 13880, 59370, 30883, 12524,
#        23571, 29059, 67151, 78203, 14011, 45275, 50588, 48076, 36048,
#        29692, 39458, 51070, 41214, 73392, 61710, 53366, 26182, 43559,
#        77736, 27510, 17927, 31723, 39797, 48392, 68828, 44161, 47644,
#        63234, 29657, 31841, 80234, 17786, 66428, 73442, 79174, 65405,
#        18227, 51005, 74436,  1920, 49518,  1736, 75386, 34317, 51974,
#        40484,  6698, 17525, 62793, 54388, 39356, 54633,  5857, 18042,
#        76544, 72434, 23588, 26620, 22503, 24096,  5454, 34831, 34889,
#         3398, 41106, 72472, 66366, 26280, 26416,  6270, 13580, 34633,
#        63538, 30325, 34315,  9009, 62637,  4972, 28753, 55095, 57026,
# ...

# %%
ufosDS = ufos.loc[downSampleMask]
ufosDS
# Out:
#                      date                              city    state  country  \
# 17264 1994-12-01 01:00:00           rio de janeiro (brazil)  unknown  unknown
# 53557 2013-06-04 13:30:00                         st. louis       mo       us
# 73088 2001-09-11 09:00:00                        monticello       wi       us
# 68313 2004-08-21 08:30:00                        long beach       wa       us
# 72675 2008-08-09 22:15:00                           hancock       ny       us
# ...                   ...                               ...      ...      ...
# 35652 2000-04-10 21:30:00  brentwood&#44 essex (uk/england)  unknown  unknown
# 57647 2010-07-17 22:20:00                      blue springs       mo       us
# 32833 2002-03-02 20:20:00                             malta       mt       us
# 24715 2003-01-05 00:00:00          greenfield park (canada)       pq       ca
# 53173 2009-06-30 22:11:00                             flint       mi       us
#
# ...

# %%
plt.scatter?

# %% [markdown]
# # Part 1

# %% [markdown]
# https://coderzcolumn.com/tutorials/data-science/interactive-charts-using-matplotlib-and-ipywidgets
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html
# week 05 code from teacher

# %%
@ipywidgets.interact(feature1=ufosDS.columns, feature2=ufosDS.columns, colormap_name=plt.colormaps())
def create_scatter(feature1, feature2, colormap_name):
    with plt.style.context("ggplot"):
        fig = plt.figure(figsize=(12,6))
        
        plt.scatter(x = ufosDS[feature1],
                    y = ufosDS[feature2],
                    c = ufosDS[feature1],
                    cmap = colormap_name,
                    s = 30
                   )
        plt.xlabel(feature1.capitalize(), fontsize = 15)
        plt.ylabel(feature2.capitalize(), fontsize = 15)

        plt.title("%s vs %s"%(feature1.capitalize(), feature2.capitalize()))
        plt.xticks(rotation = 90, fontsize = 15)
        plt.yticks(fontsize = 15)
        plt.colorbar()
        plt.show()

#week 05 code from teacher
# @ipywidgets.interact(colormap_name=plt.colormaps(), take_log=True)
# def ufo_color(colormap_name, take_log=True):
#     if take_log:
#         norm = matplotlib.colors.SymLogNorm(10)
#     else:
#         norm = matplotlib.colors.Normalize()
#     plt.imshow(create_scatter(ufosDS.columns,ufosDS.columns), cmap=colormap_name, norm = norm)
#     plt.colorbar()
#     plt.clim(-352,352)
#     plt.show()
# Out:
# interactive(children=(Dropdown(description='feature1', options=('date', 'city', 'state', 'country', 'shape', '…

# %% [markdown]
# https://plotly.com/python/v3/figurewidget-app/

# %%
# quick hint
fig, ax = plt.subplots(figsize=(10,5))
ufosDS.hist(column='longitude', ax=ax)
plt.show()
